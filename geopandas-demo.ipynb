# %%
# try running this with Python 3 (ipykernel) and with Python (uv GeoData) Jupuyter kernel
import geopandas as gpd
import geodatasets as gds

x = gpd.read_file(gds.get_path("geoda atlanta"))

x.plot()
# Out:
# <Axes: >
